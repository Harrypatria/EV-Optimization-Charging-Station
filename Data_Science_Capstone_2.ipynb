# %% [markdown]
# # EV Charging Station Siting Analysis
# ### Modified by Dr. Harry Patria at Patria & Co.

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem Outline and Target Audience](#introduction)
# * [Data Sources](#data)
# * [Methodology](#methodology)
# * [Results](#results)
# * [Discussion](#discussion)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction: Business Problem Outline and Target Audience <a name="introduction"></a>

# %% [markdown]
# _Background:_ This piece of code was written as part of the requirements of the IBM/Coursera Data Science Professional Career Track Specialization. Students were asked to choose a problem and utilize skills acquired during this specialization to solve the selected problem.<br>
#
# _Business Problem Outline_ <br>
#
# Electric Vehicles (EVs) are gaining popularity due to absence of local emissions, and certain technical advantages that EVs have over conventional vehicles (faster acceleration, no need for periodic service requirements etc.). This is not to say that there are no barriers to the widespread acceptance of EVs. One of the primary drawbacks is the lack of access to charging equipments at public locations.<br>
#
# In this project, we look at the city of Raleigh in North Carolina, where I currently reside. The objective is try to come up with a siting analysis for public EV charging station installations - preferably close to local shops and restaurants so that people can charge their cars while getting groceries or sharing a meal with their loved ones. One of the indirect benefits of EV charging that is often talked about is contribution to the local economy - i.e. people tend to spend money on nearby shops when waiting on charging their EVs <br>
#
# To be specific, the area of interest in this case is within a 100 km radius of downtown Raleigh in North Carolina. This approximately covers the towns of Durham, Raleigh and Chapel Hill. As of 2020, the population of the larger Raleigh-Durham-Chapel Hill Combined Statistical Area (CSA) is estimated at 2.03 million. Hailed as a technological hub within the state, the mean age of residents range between between 26 to 35 years. This area may be considered a suitable case study location for testing out algorithms ranking retail facilities that could benefit from EV charger installations. <br>
#
# Note that the approach that I am taking is pretty simplistic - I am aiming to identify retail locations (primarily grocery shops, restauraunts and some service industries) that have relatively few EV chargers in the vicinity. A list of suitable retail locations that could benefit from an EV charging installation in its neighborhood is provided as input to a clustering algorithm. This algorithm determines locations that could improve access to EV charging in our region of interest. <br>
#
# Outputs include a map with clusters of retail locations that could benefit from EV charger installations and a list of suitable locations for EV charging installations.
#
# _Target Audience_ <br>
#
# This project is primarily aimed at any one interested in Data Science applications in the Energy sector, but I hope that other Data Science enthusiasts will also find ways to repurpose the code. Data Science techniques and/or Machine Learning Algorithms often continue to remain abstract ideas until we apply them to problems. I hope this project provides some insight into translating abstract ideas into specific outputs that could aid decision making in business ventures.

# %% [markdown]
# ## Data Sources <a name="data"></a>

# %% [markdown]
# The following publicly available data-sets have been used to perform the analysis
# 1. <a href = "https://foursquare.com/"> API Foursquare - This database provides information on locations of popular restaurants </a>
# 2. <a href = "https://afdc.energy.gov/fuels/electricity_locations.html#/find/nearest?fuel=ELEC"> AFDC Database - This database provides information on preexisting EV charging locations </a>

# %% [markdown]
# ## Methodology <a name="methodology"></a>

# %% [markdown]
# __Step 0__: Import relevant Python libraries

# %%
# Following line needs to be uncommented if geopy is not installed
#!conda install -c conda-forge geopy --yes 
#!pip3.9 install geopy
# Following line needs to be uncommented if geopy is not installed
#!conda install -c conda-forge folium=0.5.0 --yes
#!pip3.9 install folium
from functools import partial
#import geopy.geocoders
from geopy.geocoders import Nominatim
#install openpyxl
#!pip3.9 install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.10
# WARNING: You are using pip version 21.3.1; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\users\harry patria\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd # this library offers data structures and operations for manipulating numerical tables 
import numpy as np # this library is used for Scientific Computing

import requests # library to handle requests
import random # library for random number generation

from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# Import libraries for clustering analysis
import sklearn.neighbors
from sklearn.cluster import KMeans

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

import folium # plotting library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# __Step 1__: Read in the data from AFDC and Foursquare API

# %%
# Importing locations of existing public EVSE chargers from AFDC
EVSE = pd.read_excel(open('AFDC_Data.xlsx','rb'), sheet_name='AFDC_Master_Data_NC')
EVSE.head()
# Out:
#                            Station Name      Street Address          City  \
# 0                           DUKE ENERGY       410 S Mint St     Charlotte
# 1  City of Raleigh - Municipal Building    285 W Hargett St       Raleigh
# 2            City of Raleigh - Downtown   215 W Cabarrus St       Raleigh
# 3               Modern Nissan - Concord  967 Concord Pkwy S       Concord
# 4                  Fred Anderson Nissan     4559 Raeford Rd  Fayetteville
#
#      ZIP  EV Level1 EVSE Num  EV Level2 EVSE Num  EV DC Fast Count   Latitude  \
# 0  28202                 NaN                 1.0               NaN  35.226914
# 1  27601                 NaN                 2.0               NaN  35.778416
# 2  27601                 NaN                 1.0               NaN  35.774350
# 3  28027                 NaN                 1.0               1.0  35.392063
# 4  28304                 NaN                 1.0               1.0  35.042419
#
#    Longitude Date Last Confirmed     ID
# 0 -80.850182          2020-05-17  38892
# 1 -78.643470          2019-11-08  39016
# 2 -78.642287          2019-11-08  39017
# 3 -80.622777          2019-09-09  40066
# 4 -78.956747          2019-09-09  40067

# %%
# Use Foursquare API to download places of interest within the RDU-Chapel Hill Area

# %% [markdown]
# Following cell contains foursquare API credentials and has been removed from public view

# %%
CLIENT_ID = '3LV40XKAW4DLMFQYMKV4V2EU0L1TCFVLCQ5PMVIGX44YT4GP' # your Foursquare ID
CLIENT_SECRET = 'ES2DAIMEHEO4KSY2YENFMUHCPMOVDLXPA1PVME3XQZQATFIB' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 500
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 3LV40XKAW4DLMFQYMKV4V2EU0L1TCFVLCQ5PMVIGX44YT4GP
# CLIENT_SECRET:ES2DAIMEHEO4KSY2YENFMUHCPMOVDLXPA1PVME3XQZQATFIB

# %%
# Testing connection with Foursquare API

address = '4242 Six Forks Rd, Raleigh, NC 27609'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 35.83801365 -78.64074000129678

# %% [markdown]
# Next up - identification of trending spots in the Raleigh... <br> There are a few different ways of identifying trending spots. For purposes of this project we consider two specific Foursquare categories:<br>
# (a) 'Food', and (b) 'Shops & Services'. <br> Refer to <a href = "https://developer.foursquare.com/docs/build-with-foursquare/categories/"> API Foursquare List of Venue Categories </a> for full list of categories

# %% [markdown]
# URI to search for a specific venue category
# > `https://api.foursquare.com/v2/venues/`**search**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&query=`**QUERY**`&radius=`**RADIUS**`&limit=`**LIMIT**

# %% [markdown]
# For reference, here is the <a href = "https://developer.foursquare.com/docs/build-with-foursquare/categories/"> link </a> to Foursquare API's webpage that lists all parameter definitions for URI

# %%
#
search_query = 'Shops & Services'
radius = 100000 # radius in meters
LIMIt = 500 # Limit on number of venues
print(search_query + ' .... OK!')
# Out:
# Shops & Services .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=3LV40XKAW4DLMFQYMKV4V2EU0L1TCFVLCQ5PMVIGX44YT4GP&client_secret=ES2DAIMEHEO4KSY2YENFMUHCPMOVDLXPA1PVME3XQZQATFIB&ll=35.83801365,-78.64074000129678&v=20180604&query=Shops & Services&radius=100000&limit=500'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '62c8399ba1401f6a227c7fc9'},
#  'response': {'venues': [{'id': '4ad4c00af964a52037ed20e3',
#     'name': 'Shops of Cameron Village',
#     'location': {'address': '2034 Cameron St',
#      'crossStreet': 'at Daniels St',
#      'lat': 35.791233,
#      'lng': -78.660793,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.791233,
#        'lng': -78.660793}],
#      'distance': 5513,
#      'postalCode': '27605',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['2034 Cameron St (at Daniels St)',
#       'Raleigh, NC 27605',
#       'United States']},
#     'categories': [{'id': '5744ccdfe4b0c0459246b4dc',
#       'name': 'Shopping Plaza',
#       'pluralName': 'Shopping Plazas',
#       'shortName': 'Shopping Plaza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '61850785'},
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '4ddbfc573151ee0807532b88',
#     'name': 'Shops of Cameron Village CAT Bus Stop',
#     'location': {'address': 'Cameron at Daniels',
#      'lat': 35.79120760073099,
#      'lng': -78.66097431740017,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.79120760073099,
#        'lng': -78.66097431740017}],
#      'distance': 5521,
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['Cameron at Daniels',
#       'Raleigh, NC',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fe931735',
#       'name': 'Bus Station',
#       'pluralName': 'Bus Stations',
#       'shortName': 'Bus Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '4b5eebaff964a520f79d29e3',
#     'name': 'Park Shops',
#     'location': {'address': '101 Current Dr',
#      'crossStreet': 'at North Carolina State University',
#      'lat': 35.7854910218201,
#      'lng': -78.66735527557647,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.7854910218201,
#        'lng': -78.66735527557647}],
#      'distance': 6321,
#      'postalCode': '27695',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['101 Current Dr (at North Carolina State University)',
#       'Raleigh, NC 27695',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d198941735',
#       'name': 'College Academic Building',
#       'pluralName': 'College Academic Buildings',
#       'shortName': 'Academic Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/academicbuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '52c81e8811d2d004d457e8ba',
#     'name': 'Bass Pro Shops',
#     'location': {'address': '801 Bass Pro Ln',
#      'crossStreet': 'N Harrison Ave',
#      'lat': 35.8303096,
#      'lng': -78.7707037,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.8303096,
#        'lng': -78.7707037},
#       {'label': 'entrance', 'lat': 35.83038, 'lng': -78.771849}],
#      'distance': 11760,
#      'postalCode': '27513',
#      'cc': 'US',
#      'city': 'Cary',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['801 Bass Pro Ln (N Harrison Ave)',
#       'Cary, NC 27513',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f2941735',
#       'name': 'Sporting Goods Shop',
#       'pluralName': 'Sporting Goods Shops',
#       'shortName': 'Sporting Goods',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '500552e8e4b0b02ea225c44d',
#     'name': 'Park Shops 201',
#     'location': {'address': 'Stinson Drive',
#      'lat': 35.78537071485849,
#      'lng': -78.66772711538182,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.78537071485849,
#        'lng': -78.66772711538182}],
#      'distance': 6346,
#      'postalCode': '27607',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['Stinson Drive',
#       'Raleigh, NC 27607',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1a0941735',
#       'name': 'College Classroom',
#       'pluralName': 'College Classrooms',
#       'shortName': 'Classroom',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/classroom_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '5c3fcfaf35811b002cdeccf1',
#     'name': 'Shops At Mcneil Pointe',
#     'location': {'lat': 35.81268494095342,
#      'lng': -78.62709611979503,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.81268494095342,
#        'lng': -78.62709611979503}],
#      'distance': 3076,
#      'postalCode': '27608',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['Raleigh, NC 27608', 'United States']},
#     'categories': [{'id': '5744ccdfe4b0c0459246b4dc',
#       'name': 'Shopping Plaza',
#       'pluralName': 'Shopping Plazas',
#       'shortName': 'Shopping Plaza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '4f8991ffe4b039b1452f46ec',
#     'name': 'Shops at Brennan Station',
#     'location': {'address': '8111 Creedmoor Rd',
#      'lat': 35.89934409380653,
#      'lng': -78.68227260885016,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.89934409380653,
#        'lng': -78.68227260885016}],
#      'distance': 7787,
#      'postalCode': '27613',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['8111 Creedmoor Rd',
#       'Raleigh, NC 27613',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fd941735',
#       'name': 'Shopping Mall',
#       'pluralName': 'Shopping Malls',
#       'shortName': 'Mall',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '598d59efc0cacb28d87e65cc',
#     'name': 'Shops at Town Station',
#     'location': {'address': '1000 Ballena Cir',
#      'lat': 35.77165420000001,
#      'lng': -78.8066887,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.77165420000001,
#        'lng': -78.8066887}],
#      'distance': 16704,
#      'postalCode': '27513',
#      'cc': 'US',
#      'city': 'Cary',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['1000 Ballena Cir',
#       'Cary, NC 27513',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fd941735',
#       'name': 'Shopping Mall',
#       'pluralName': 'Shopping Malls',
#       'shortName': 'Mall',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '5244ccfd11d2ba80c1e257f0',
#     'name': 'Flip Flop Shops',
#     'location': {'address': '4325 Glenwood Avenue #2070',
#      'crossStreet': 'Creedmore Rd.',
#      'lat': 35.84071461254494,
#      'lng': -78.6817076673406,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.84071461254494,
#        'lng': -78.6817076673406}],
#      'distance': 3709,
#      'postalCode': '27612',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['4325 Glenwood Avenue #2070 (Creedmore Rd.)',
#       'Raleigh, NC 27612',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d103951735',
#       'name': 'Clothing Store',
#       'pluralName': 'Clothing Stores',
#       'shortName': 'Apparel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '588077651'},
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '4ec6b4edb8f758db73456f1c',
#     'name': 'Shops at Oberlin Court',
#     'location': {'address': 'Oberlin Road',
#      'crossStreet': 'Wade Ave',
#      'lat': 35.79796835609879,
#      'lng': -78.65985157658943,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.79796835609879,
#        'lng': -78.65985157658943}],
#      'distance': 4779,
#      'postalCode': '27608',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['Oberlin Road (Wade Ave)',
#       'Raleigh, NC 27608',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fd941735',
#       'name': 'Shopping Mall',
#       'pluralName': 'Shopping Malls',
#       'shortName': 'Mall',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '4f679d65e4b045fbd69983c1',
#     'name': 'shops of Lafayette Village',
#     'location': {'address': 'Honeycutt Rd, Raleigh, NC',
#      'lat': 35.91530299466403,
#      'lng': -78.61650194193825,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.91530299466403,
#        'lng': -78.61650194193825}],
#      'distance': 8877,
#      'postalCode': '27614',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['Honeycutt Rd, Raleigh, NC',
#       'Raleigh, NC 27614',
#       'United States']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '4d0c36cd5c46a0933d5c07b4',
#     'name': 'Shops',
#     'location': {'lat': 35.755007,
#      'lng': -78.774843,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.755007,
#        'lng': -78.774843}],
#      'distance': 15231,
#      'postalCode': '27511',
#      'cc': 'US',
#      'city': 'Cary',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['Cary, NC 27511', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f6941735',
#       'name': 'Department Store',
#       'pluralName': 'Department Stores',
#       'shortName': 'Department Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '50d626b9e4b047bb01fc6e06',
#     'name': "Suzio's Boutique (at Shops of Baileywick)",
#     'location': {'address': '9650 Strickland Rd, Harvest Plaza',
#      'lat': 35.90452033860553,
#      'lng': -78.65714192390442,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.90452033860553,
#        'lng': -78.65714192390442}],
#      'distance': 7549,
#      'postalCode': '27615',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['9650 Strickland Rd, Harvest Plaza',
#       'Raleigh, NC 27615',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d104951735',
#       'name': 'Boutique',
#       'pluralName': 'Boutiques',
#       'shortName': 'Boutique',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_boutique_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '5817844738fa2b62ad9e0a9d',
#     'name': 'Shopsmith Repair/Woodworking Academy',
#     'location': {'address': '6325 Rushingbrook Dr',
#      'lat': 35.864641999999996,
#      'lng': -78.666218,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.864641999999996,
#        'lng': -78.666218},
#       {'label': 'entrance', 'lat': 35.864598, 'lng': -78.666174}],
#      'distance': 3751,
#      'postalCode': '27612',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['6325 Rushingbrook Dr',
#       'Raleigh, NC 27612',
#       'United States']},
#     'categories': [{'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'shortName': 'Home Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '360527652'},
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '53b16c7c11d217881a958de3',
#     'name': 'Rainbow Shops',
#     'location': {'address': '6431 Triangle Plantation Dr',
#      'lat': 35.873154,
#      'lng': -78.58245600000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.873154,
#        'lng': -78.58245600000001},
#       {'label': 'entrance', 'lat': 35.873166, 'lng': -78.582381}],
#      'distance': 6553,
#      'postalCode': '27616',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['6431 Triangle Plantation Dr',
#       'Raleigh, NC 27616',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d108951735',
#       'name': "Women's Store",
#       'pluralName': "Women's Stores",
#       'shortName': "Women's Store",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_women_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '5c74d107ad17890039a6ddc4',
#     'name': 'Rainbow Shops',
#     'location': {'address': '3665 New Bern Ave',
#      'lat': 35.7985924,
#      'lng': -78.5794926,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.7985924,
#        'lng': -78.5794926}],
#      'distance': 7058,
#      'postalCode': '27610',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['3665 New Bern Ave',
#       'Raleigh, NC 27610',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d108951735',
#       'name': "Women's Store",
#       'pluralName': "Women's Stores",
#       'shortName': "Women's Store",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_women_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '50d6249fe4b05cc5d8b91194',
#     'name': 'Fun and Fabulous (at Shops of Baileywick)',
#     'location': {'address': '9650 Strickland Road, Harvest Plaza',
#      'lat': 35.90451431274414,
#      'lng': -78.65711212158203,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.90451431274414,
#        'lng': -78.65711212158203}],
#      'distance': 7548,
#      'postalCode': '27615',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['9650 Strickland Road, Harvest Plaza',
#       'Raleigh, NC 27615',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ff941735',
#       'name': 'Miscellaneous Shop',
#       'pluralName': 'Miscellaneous Shops',
#       'shortName': 'Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '50d622a9e4b0afbc157a81df',
#     'name': 'Fancy That by A&E (at Shops of Baileywick)',
#     'location': {'address': '9650 Strickland Rd, Harvest Plaza',
#      'lat': 35.90452902891267,
#      'lng': -78.65715265274048,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.90452902891267,
#        'lng': -78.65715265274048}],
#      'distance': 7550,
#      'postalCode': '27615',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['9650 Strickland Rd, Harvest Plaza',
#       'Raleigh, NC 27615',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f8941735',
#       'name': 'Furniture / Home Store',
#       'pluralName': 'Furniture / Home Stores',
#       'shortName': 'Furniture / Home',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '4c37acb32c8020a1237b8900',
#     'name': 'Seaboard Ace Hardware',
#     'location': {'address': '802 Semart Dr Suite 112',
#      'crossStreet': 'at Seaboard Ave',
#      'lat': 35.790212536745734,
#      'lng': -78.64000797271729,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.790212536745734,
#        'lng': -78.64000797271729}],
#      'distance': 5321,
#      'postalCode': '27604',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['802 Semart Dr Suite 112 (at Seaboard Ave)',
#       'Raleigh, NC 27604',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d112951735',
#       'name': 'Hardware Store',
#       'pluralName': 'Hardware Stores',
#       'shortName': 'Hardware',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '4cd48da6dfb4a1cdaddb535c',
#     'name': 'Blake Street Shops & Studios',
#     'location': {'address': '300 Blake St',
#      'lat': 35.775879923408596,
#      'lng': -78.63593806634475,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.775879923408596,
#        'lng': -78.63593806634475}],
#      'distance': 6930,
#      'postalCode': '27601',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['300 Blake St',
#       'Raleigh, NC 27601',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '56fc983f498eb458f4de1bb0',
#     'name': 'The Shops at Garner Plaza',
#     'location': {'address': '531 Plaza Cir',
#      'lat': 35.704786999999996,
#      'lng': -78.611581,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.704786999999996,
#        'lng': -78.611581},
#       {'label': 'entrance', 'lat': 35.704405, 'lng': -78.611727}],
#      'distance': 15062,
#      'postalCode': '27529',
#      'cc': 'US',
#      'city': 'Garner',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['531 Plaza Cir',
#       'Garner, NC 27529',
#       'United States']},
#     'categories': [{'id': '5744ccdfe4b0c0459246b4dc',
#       'name': 'Shopping Plaza',
#       'pluralName': 'Shopping Plazas',
#       'shortName': 'Shopping Plaza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '4dfb628881dce49306247d19',
#     'name': 'Lafayette Village',
#     'location': {'address': '8450 Honeycutt Rd',
#      'crossStreet': 'at Falls of Neuse Rd',
#      'lat': 35.89509513883663,
#      'lng': -78.62159192562103,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.89509513883663,
#        'lng': -78.62159192562103},
#       {'label': 'entrance', 'lat': 35.895131, 'lng': -78.622062}],
#      'distance': 6584,
#      'postalCode': '27615',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['8450 Honeycutt Rd (at Falls of Neuse Rd)',
#       'Raleigh, NC 27615',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fd941735',
#       'name': 'Shopping Mall',
#       'pluralName': 'Shopping Malls',
#       'shortName': 'Mall',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '503dede4e4b04bf662da7137',
#     'name': 'The Shops at Preston',
#     'location': {'lat': 35.800481926740616,
#      'lng': -78.81747803524213,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.800481926740616,
#        'lng': -78.81747803524213}],
#      'distance': 16491,
#      'postalCode': '27513',
#      'cc': 'US',
#      'city': 'Cary',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['Cary, NC 27513', 'United States']},
#     'categories': [{'id': '5744ccdfe4b0c0459246b4dc',
#       'name': 'Shopping Plaza',
#       'pluralName': 'Shopping Plazas',
#       'shortName': 'Shopping Plaza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '4adcd1c2f964a520353021e3',
#     'name': 'Target',
#     'location': {'address': '7900 Old Wake Forest Rd',
#      'crossStreet': 'at Triangle Town Blvd.',
#      'lat': 35.86585,
#      'lng': -78.567986,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.86585,
#        'lng': -78.567986}],
#      'distance': 7259,
#      'postalCode': '27616',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['7900 Old Wake Forest Rd (at Triangle Town Blvd.)',
#       'Raleigh, NC 27616',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b42',
#       'name': 'Big Box Store',
#       'pluralName': 'Big Box Stores',
#       'shortName': 'Big Box Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '582a3df92fea3661ea3cedb7',
#     'name': 'Shop Small Super Shop',
#     'location': {'address': '656 Maywood Ave',
#      'lat': 35.76164627075195,
#      'lng': -78.65709686279297,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.76164627075195,
#        'lng': -78.65709686279297}],
#      'distance': 8628,
#      'postalCode': '27603',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['656 Maywood Ave',
#       'Raleigh, NC 27603',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b3d',
#       'name': 'Pop-Up Shop',
#       'pluralName': 'Pop-Up Shops',
#       'shortName': 'Pop-Up Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '5181335f498e208c89e05294',
#     'name': 'The Shops at Timber Landing shopping center',
#     'location': {'lat': 35.68486612730721,
#      'lng': -78.61634901598707,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.68486612730721,
#        'lng': -78.61634901598707}],
#      'distance': 17189,
#      'cc': 'US',
#      'city': 'Garner',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['Garner, NC', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ff941735',
#       'name': 'Miscellaneous Shop',
#       'pluralName': 'Miscellaneous Shops',
#       'shortName': 'Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '5db9dfaf9708410007f980a0',
#     'name': 'Rainbow Shops',
#     'location': {'address': '1004 Shoppes At Midway Dr',
#      'lat': 35.798753,
#      'lng': -78.507796,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.798753,
#        'lng': -78.507796}],
#      'distance': 12771,
#      'postalCode': '27545',
#      'cc': 'US',
#      'city': 'Knightdale',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['1004 Shoppes At Midway Dr',
#       'Knightdale, NC 27545',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d108951735',
#       'name': "Women's Store",
#       'pluralName': "Women's Stores",
#       'shortName': "Women's Store",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_women_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '4f05f4be2c5b4138bfa60dda',
#     'name': 'Paradies Shops',
#     'location': {'address': 'Raleigh-Durham International Airport, 2400 W Terminal Blvd, Morrisville, NC 27560',
#      'lat': 35.87591941982914,
#      'lng': -78.78746188485546,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.87591941982914,
#        'lng': -78.78746188485546}],
#      'distance': 13893,
#      'postalCode': '27560',
#      'cc': 'US',
#      'city': 'Morrisville',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['Raleigh-Durham International Airport, 2400 W Terminal Blvd, Morrisville, NC 27560',
#       'Morrisville, NC 27560',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ff941735',
#       'name': 'Miscellaneous Shop',
#       'pluralName': 'Miscellaneous Shops',
#       'shortName': 'Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '4eff4f42c5126f14b701f754',
#     'name': 'Rainbow Shops',
#     'location': {'address': '4430 Fayetteville Rd',
#      'lat': 35.71997887403511,
#      'lng': -78.65692140976392,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.71997887403511,
#        'lng': -78.65692140976392}],
#      'distance': 13220,
#      'postalCode': '27603',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['4430 Fayetteville Rd',
#       'Raleigh, NC 27603',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d108951735',
#       'name': "Women's Store",
#       'pluralName': "Women's Stores",
#       'shortName': "Women's Store",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_women_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '4e889fb3b803a8abf60f5d0c',
#     'name': 'Market Shoppes at the State Farmers Market',
#     'location': {'address': '1201 Agriculture St',
#      'lat': 35.76308207952598,
#      'lng': -78.66305720204306,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.76308207952598,
#        'lng': -78.66305720204306}],
#      'distance': 8581,
#      'postalCode': '27603',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['1201 Agriculture St',
#       'Raleigh, NC 27603',
#       'United States']},
#     'categories': [{'id': '50be8ee891d4fa8dcc7199a7',
#       'name': 'Market',
#       'pluralName': 'Markets',
#       'shortName': 'Market',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/market_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '518293bf498ed11428c36841',
#     'name': 'Upscale Thrift Shops',
#     'location': {'address': '5905 Fayetteville Rd',
#      'lat': 35.697364807128906,
#      'lng': -78.67202758789062,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.697364807128906,
#        'lng': -78.67202758789062}],
#      'distance': 15909,
#      'postalCode': '27603',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['5905 Fayetteville Rd',
#       'Raleigh, NC 27603',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d101951735',
#       'name': 'Thrift / Vintage Store',
#       'pluralName': 'Thrift / Vintage Stores',
#       'shortName': 'Thrift / Vintage',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '5facb9cc0b1a3b47f029a4e9',
#     'name': 'Bass Pro Shops/Cabela’s Boating Center',
#     'location': {'address': '201 Cabela Dr',
#      'lat': 35.6983979,
#      'lng': -78.5811666,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.6983979,
#        'lng': -78.5811666}],
#      'distance': 16446,
#      'postalCode': '27529',
#      'cc': 'US',
#      'city': 'Garner',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['201 Cabela Dr',
#       'Garner, NC 27529',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d12d951735',
#       'name': 'Boat or Ferry',
#       'pluralName': 'Boats or Ferries',
#       'shortName': 'Boat / Ferry',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/boat_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '4bf97f0c508c0f4713583f31',
#     'name': 'North Carolina Specialty Shops',
#     'location': {'lat': 35.978061655754715,
#      'lng': -78.50987541007909,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.978061655754715,
#        'lng': -78.50987541007909}],
#      'distance': 19551,
#      'postalCode': '27587',
#      'cc': 'US',
#      'city': 'Wake Forest',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['Wake Forest, NC 27587', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d128951735',
#       'name': 'Gift Shop',
#       'pluralName': 'Gift Shops',
#       'shortName': 'Gift Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/giftshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '4ebb03ea4690c31362522208',
#     'name': 'Andrews Shop Southern Industrial',
#     'location': {'lat': 35.89292907714844,
#      'lng': -78.75028991699219,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.89292907714844,
#        'lng': -78.75028991699219}],
#      'distance': 11620,
#      'postalCode': '27617',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['Raleigh, NC 27617', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124951735',
#       'name': 'Automotive Shop',
#       'pluralName': 'Automotive Shops',
#       'shortName': 'Automotive',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '582cdc00c3fe2920e1d5b14f',
#     'name': 'Old Town Market Shops',
#     'location': {'address': '11900 Louisburg Rd',
#      'crossStreet': '401',
#      'lat': 35.948465999999996,
#      'lng': -78.42191,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.948465999999996,
#        'lng': -78.42191},
#       {'label': 'entrance', 'lat': 35.948457, 'lng': -78.421946}],
#      'distance': 23251,
#      'postalCode': '27587',
#      'cc': 'US',
#      'city': 'Wake Forest',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['11900 Louisburg Rd (401)',
#       'Wake Forest, NC 27587',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d104951735',
#       'name': 'Boutique',
#       'pluralName': 'Boutiques',
#       'shortName': 'Boutique',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_boutique_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '4b22c664f964a520544d24e3',
#     'name': 'Exxon',
#     'location': {'address': '4601 Durham Rd',
#      'lat': 35.987239837646484,
#      'lng': -78.6784896850586,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.987239837646484,
#        'lng': -78.6784896850586}],
#      'distance': 16956,
#      'postalCode': '27614',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['4601 Durham Rd',
#       'Raleigh, NC 27614',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d113951735',
#       'name': 'Gas Station',
#       'pluralName': 'Gas Stations',
#       'shortName': 'Gas Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '4ebdb8cf7ee54e4cd1bc2166',
#     'name': 'Shops On Main',
#     'location': {'lat': 35.593814804966115,
#      'lng': -78.77954419565597,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.593814804966115,
#        'lng': -78.77954419565597}],
#      'distance': 29939,
#      'postalCode': '27526',
#      'cc': 'US',
#      'city': 'Fuquay-Varina',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['Fuquay-Varina, NC 27526', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d104951735',
#       'name': 'Boutique',
#       'pluralName': 'Boutiques',
#       'shortName': 'Boutique',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_boutique_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '509c209ee4b0bbf775157657',
#     'name': 'Creedmoor Village Shopping Center',
#     'location': {'address': 'NC Highway 98',
#      'crossStreet': 'at Old Creedmoor Rd.',
#      'lat': 35.9902791452231,
#      'lng': -78.69413824965457,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.9902791452231,
#        'lng': -78.69413824965457}],
#      'distance': 17620,
#      'postalCode': '27587',
#      'cc': 'US',
#      'city': 'Wake Forest',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['NC Highway 98 (at Old Creedmoor Rd.)',
#       'Wake Forest, NC 27587',
#       'United States']},
#     'categories': [{'id': '5744ccdfe4b0c0459246b4dc',
#       'name': 'Shopping Plaza',
#       'pluralName': 'Shopping Plazas',
#       'shortName': 'Shopping Plaza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '5b1f41f42b9844002c19f61b',
#     'name': 'Shops at Erwin Mill',
#     'location': {'address': '737 9th St',
#      'lat': 36.009785426488556,
#      'lng': -78.92263233661652,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.009785426488556,
#        'lng': -78.92263233661652}],
#      'distance': 31801,
#      'postalCode': '27705',
#      'cc': 'US',
#      'city': 'Durham',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['737 9th St', 'Durham, NC 27705', 'United States']},
#     'categories': [{'id': '5744ccdfe4b0c0459246b4dc',
#       'name': 'Shopping Plaza',
#       'pluralName': 'Shopping Plazas',
#       'shortName': 'Shopping Plaza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '4bbb9919ed7776b013a83e51',
#     'name': 'Sharing Shop @ SEBTS',
#     'location': {'address': '101-199 N Wingate St',
#      'lat': 35.983794701227055,
#      'lng': -78.51368481602324,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.983794701227055,
#        'lng': -78.51368481602324}],
#      'distance': 19864,
#      'postalCode': '27587',
#      'cc': 'US',
#      'city': 'Wake Forest',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['101-199 N Wingate St',
#       'Wake Forest, NC 27587',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1a8941735',
#       'name': 'General College & University',
#       'pluralName': 'General Colleges & Universities',
#       'shortName': 'Education',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '4c44cfe4dd1f2d7fc26280f9',
#     'name': 'Striking Results Pro Shop south',
#     'location': {'address': '6701 Fayetteville Rd',
#      'lat': 35.685099650681,
#      'lng': -78.68382141467497,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.685099650681,
#        'lng': -78.68382141467497},
#       {'label': 'entrance', 'lat': 35.685011, 'lng': -78.683608}],
#      'distance': 17461,
#      'postalCode': '27603',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['6701 Fayetteville Rd',
#       'Raleigh, NC 27603',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f2941735',
#       'name': 'Sporting Goods Shop',
#       'pluralName': 'Sporting Goods Shops',
#       'shortName': 'Sporting Goods',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '53b16c7c11d217881a958e2d',
#     'name': 'Rainbow Shops',
#     'location': {'address': '1058 W Club Blvd',
#      'lat': 36.020189,
#      'lng': -78.908473,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.020189,
#        'lng': -78.908473}],
#      'distance': 31522,
#      'postalCode': '27701',
#      'cc': 'US',
#      'city': 'Durham',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['1058 W Club Blvd',
#       'Durham, NC 27701',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d108951735',
#       'name': "Women's Store",
#       'pluralName': "Women's Stores",
#       'shortName': "Women's Store",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_women_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '4f70b6f6e4b00d1a930eebfd',
#     'name': 'Rainbow Shops',
#     'location': {'address': '3500 N Roxboro Rd',
#      'lat': 36.03898351055075,
#      'lng': -78.89357097420503,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.03898351055075,
#        'lng': -78.89357097420503}],
#      'distance': 31933,
#      'postalCode': '27704',
#      'cc': 'US',
#      'city': 'Durham',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['3500 N Roxboro Rd',
#       'Durham, NC 27704',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d108951735',
#       'name': "Women's Store",
#       'pluralName': "Women's Stores",
#       'shortName': "Women's Store",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_women_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '4b58c628f964a520766a28e3',
#     'name': 'Eastgate Crossing',
#     'location': {'address': '1800 E Franklin St',
#      'lat': 35.9353267,
#      'lng': -79.0254736,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.9353267,
#        'lng': -79.0254736}],
#      'distance': 36350,
#      'postalCode': '27514',
#      'cc': 'US',
#      'city': 'Chapel Hill',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['1800 E Franklin St',
#       'Chapel Hill, NC 27514',
#       'United States']},
#     'categories': [{'id': '5744ccdfe4b0c0459246b4dc',
#       'name': 'Shopping Plaza',
#       'pluralName': 'Shopping Plazas',
#       'shortName': 'Shopping Plaza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '4bf3df9e98ac0f47e24863a8',
#     'name': 'Meadowmont Village',
#     'location': {'lat': 35.90516369190238,
#      'lng': -79.01083501463107,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.90516369190238,
#        'lng': -79.01083501463107}],
#      'distance': 34211,
#      'postalCode': '27517',
#      'cc': 'US',
#      'city': 'Chapel Hill',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['Chapel Hill, NC 27517', 'United States']},
#     'categories': [{'id': '4f2a25ac4b909258e854f55f',
#       'name': 'Neighborhood',
#       'pluralName': 'Neighborhoods',
#       'shortName': 'Neighborhood',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '548b929f498e439cbf966a5c',
#     'name': 'Ashley Shops',
#     'location': {'address': '431 W Franklin St shop 213',
#      'lat': 35.90972137451172,
#      'lng': -79.06271362304688,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.90972137451172,
#        'lng': -79.06271362304688}],
#      'distance': 38891,
#      'postalCode': '27517',
#      'cc': 'US',
#      'city': 'Chapel Hill',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['431 W Franklin St shop 213',
#       'Chapel Hill, NC 27517',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f8941735',
#       'name': 'Furniture / Home Store',
#       'pluralName': 'Furniture / Home Stores',
#       'shortName': 'Furniture / Home',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '4cd30f00ecc3a09386689893',
#     'name': 'The Shops At Daniel Boone',
#     'location': {'address': '113 Daniel Boone St',
#      'lat': 36.05128229029437,
#      'lng': -79.10303128129166,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.05128229029437,
#        'lng': -79.10303128129166}],
#      'distance': 47951,
#      'postalCode': '27278',
#      'cc': 'US',
#      'city': 'Hillsborough',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['113 Daniel Boone St',
#       'Hillsborough, NC 27278',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d116951735',
#       'name': 'Antique Shop',
#       'pluralName': 'Antique Shops',
#       'shortName': 'Antiques',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/antique_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '59c966e435f9830719f9a714',
#     'name': 'L & D Shop Solutions LLC',
#     'location': {'address': '235 Medical Dr',
#      'lat': 35.511676,
#      'lng': -78.74297299999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.511676,
#        'lng': -78.74297299999999}],
#      'distance': 37485,
#      'postalCode': '27501',
#      'cc': 'US',
#      'city': 'Angier',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['235 Medical Dr',
#       'Angier, NC 27501',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124951735',
#       'name': 'Automotive Shop',
#       'pluralName': 'Automotive Shops',
#       'shortName': 'Automotive',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '4d1a13a781cea35dfed2f9ec',
#     'name': 'Court Square Shops',
#     'location': {'address': '108 S Churton St',
#      'crossStreet': 'King St',
#      'lat': 36.07504069805145,
#      'lng': -79.09952938556671,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.07504069805145,
#        'lng': -79.09952938556671}],
#      'distance': 49043,
#      'postalCode': '27278',
#      'cc': 'US',
#      'city': 'Hillsborough',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['108 S Churton St (King St)',
#       'Hillsborough, NC 27278',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d116951735',
#       'name': 'Antique Shop',
#       'pluralName': 'Antique Shops',
#       'shortName': 'Antiques',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/antique_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False},
#    {'id': '4cd0455e7f56a143d807cda6',
#     'name': 'Shops of Steele Street',
#     'location': {'address': '102 S Steele St',
#      'crossStreet': 'at Steele St & Carthage St',
#      'lat': 35.479688,
#      'lng': -79.17898199999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.479688,
#        'lng': -79.17898199999999},
#       {'label': 'entrance', 'lat': 35.479594, 'lng': -79.17832}],
#      'distance': 62936,
#      'postalCode': '27330',
#      'cc': 'US',
#      'city': 'Sanford',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['102 S Steele St (at Steele St & Carthage St)',
#       'Sanford, NC 27330',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d128951735',
#       'name': 'Gift Shop',
#       'pluralName': 'Gift Shops',
#       'shortName': 'Gift Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/giftshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289115',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
Retail_df = json_normalize(venues)
Retail_df.head()
# Out:
# C:\Users\Harry Patria\AppData\Local\Temp\ipykernel_10744\2894735463.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   Retail_df = json_normalize(venues)
#                          id                                   name  \
# 0  4ad4c00af964a52037ed20e3               Shops of Cameron Village
# 1  4ddbfc573151ee0807532b88  Shops of Cameron Village CAT Bus Stop
# 2  4b5eebaff964a520f79d29e3                             Park Shops
# 3  52c81e8811d2d004d457e8ba                         Bass Pro Shops
# 4  500552e8e4b0b02ea225c44d                         Park Shops 201
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '5744ccdfe4b0c0459246b4dc', 'name': 'S...  v-1657289115    False
# 1  [{'id': '4bf58dd8d48988d1fe931735', 'name': 'B...  v-1657289115    False
# 2  [{'id': '4bf58dd8d48988d198941735', 'name': 'C...  v-1657289115    False
# 3  [{'id': '4bf58dd8d48988d1f2941735', 'name': 'S...  v-1657289115    False
# 4  [{'id': '4bf58dd8d48988d1a0941735', 'name': 'C...  v-1657289115    False
#
#      location.address                location.crossStreet  location.lat  \
# 0     2034 Cameron St                       at Daniels St     35.791233
# 1  Cameron at Daniels                                 NaN     35.791208
# 2      101 Current Dr  at North Carolina State University     35.785491
# 3     801 Bass Pro Ln                      N Harrison Ave     35.830310
# 4       Stinson Drive                                 NaN     35.785371
#
#    location.lng                            location.labeledLatLngs  \
# 0    -78.660793  [{'label': 'display', 'lat': 35.791233, 'lng':...
# 1    -78.660974  [{'label': 'display', 'lat': 35.79120760073099...
# 2    -78.667355  [{'label': 'display', 'lat': 35.7854910218201,...
# 3    -78.770704  [{'label': 'display', 'lat': 35.8303096, 'lng'...
# 4    -78.667727  [{'label': 'display', 'lat': 35.78537071485849...
#
#    location.distance location.postalCode location.cc location.city  \
# 0               5513               27605          US       Raleigh
# 1               5521                 NaN          US       Raleigh
# 2               6321               27695          US       Raleigh
# 3              11760               27513          US          Cary
# 4               6346               27607          US       Raleigh
#
#   location.state location.country  \
# 0             NC    United States
# 1             NC    United States
# 2             NC    United States
# 3             NC    United States
# 4             NC    United States
#
#                            location.formattedAddress venuePage.id
# 0  [2034 Cameron St (at Daniels St), Raleigh, NC ...     61850785
# 1   [Cameron at Daniels, Raleigh, NC, United States]          NaN
# 2  [101 Current Dr (at North Carolina State Unive...          NaN
# 3  [801 Bass Pro Ln (N Harrison Ave), Cary, NC 27...          NaN
# 4  [Stinson Drive, Raleigh, NC 27607, United States]          NaN

# %%
# Tracking down restaurants in the area
search_query = 'Food'
radius = 100000 # radius in meters
LIMIt = 500 # Limit on number of venues
print(search_query + ' .... OK!')
# Out:
# Food .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=3LV40XKAW4DLMFQYMKV4V2EU0L1TCFVLCQ5PMVIGX44YT4GP&client_secret=ES2DAIMEHEO4KSY2YENFMUHCPMOVDLXPA1PVME3XQZQATFIB&ll=35.83801365,-78.64074000129678&v=20180604&query=Food&radius=100000&limit=500'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '62c839b3a5188f3457d6238f'},
#  'response': {'venues': [{'id': '4b22b0e6f964a520e04b24e3',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '5426 Six Forks Rd',
#      'lat': 35.854909950587164,
#      'lng': -78.64072713192202,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.854909950587164,
#        'lng': -78.64072713192202}],
#      'distance': 1880,
#      'postalCode': '27609',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['5426 Six Forks Rd',
#       'Raleigh, NC 27609',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4ed01e2b775bbb5f32900c8a',
#     'name': 'Target - Food Avenue',
#     'location': {'address': 'North Hills',
#      'lat': 35.8383193183181,
#      'lng': -78.64182136715121,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.8383193183181,
#        'lng': -78.64182136715121}],
#      'distance': 103,
#      'postalCode': '27609',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['North Hills',
#       'Raleigh, NC 27609',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4b071d63f964a52087f722e3',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '4317 Fall Of The Neuse Rd',
#      'lat': 35.84104260746239,
#      'lng': -78.61312884564886,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.84104260746239,
#        'lng': -78.61312884564886}],
#      'distance': 2514,
#      'postalCode': '27609',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['4317 Fall Of The Neuse Rd',
#       'Raleigh, NC 27609',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4ba15048f964a520a9ab37e3',
#     'name': 'Food Bank of Central & Eastern NC',
#     'location': {'address': '3808 Tarheel Dr',
#      'crossStreet': 'btwn Wolfpack Lane & St Albans Dr',
#      'lat': 35.83152395695958,
#      'lng': -78.60763895817779,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.83152395695958,
#        'lng': -78.60763895817779},
#       {'label': 'entrance', 'lat': 35.831342, 'lng': -78.607388}],
#      'distance': 3073,
#      'postalCode': '27609',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['3808 Tarheel Dr (btwn Wolfpack Lane & St Albans Dr)',
#       'Raleigh, NC 27609',
#       'United States']},
#     'categories': [{'id': '50328a8e91d4c4b30a586d6c',
#       'name': 'Non-Profit',
#       'pluralName': 'Non-Profits',
#       'shortName': 'Non-Profit',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4b8ad3d9f964a520c38332e3',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '5633 Creedmoor Rd',
#      'lat': 35.8589780724059,
#      'lng': -78.68203603004157,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.8589780724059,
#        'lng': -78.68203603004157}],
#      'distance': 4396,
#      'postalCode': '27612',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['5633 Creedmoor Rd',
#       'Raleigh, NC 27612',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4c59be6467ac0f477c00054c',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '4510 Capital Blvd',
#      'lat': 35.84529035486159,
#      'lng': -78.57903733877176,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.84529035486159,
#        'lng': -78.57903733877176}],
#      'distance': 5626,
#      'postalCode': '27604',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['4510 Capital Blvd',
#       'Raleigh, NC 27604',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4ba3ca6df964a520ad5f38e3',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '3151 Capital Blvd',
#      'lat': 35.82338354708712,
#      'lng': -78.58957946452338,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.82338354708712,
#        'lng': -78.58957946452338}],
#      'distance': 4896,
#      'postalCode': '27604',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['3151 Capital Blvd',
#       'Raleigh, NC 27604',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4ada731af964a520ae2221e3',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '3415 Avent Ferry Rd',
#      'lat': 35.76635336065073,
#      'lng': -78.69731491096347,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.76635336065073,
#        'lng': -78.69731491096347},
#       {'label': 'entrance', 'lat': 35.765984, 'lng': -78.697404}],
#      'distance': 9472,
#      'postalCode': '27606',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['3415 Avent Ferry Rd',
#       'Raleigh, NC 27606',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4ae609c1f964a52040a421e3',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '13200 Falls of Neuse Rd Ste 159',
#      'lat': 35.94102285889013,
#      'lng': -78.559376634023,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.94102285889013,
#        'lng': -78.559376634023},
#       {'label': 'entrance', 'lat': 35.940625, 'lng': -78.559617}],
#      'distance': 13613,
#      'postalCode': '27614',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['13200 Falls of Neuse Rd Ste 159',
#       'Raleigh, NC 27614',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4b2a335bf964a52003a624e3',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '1121 Falls River Ave Ste 101',
#      'lat': 35.90607806421702,
#      'lng': -78.58929306160626,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.90607806421702,
#        'lng': -78.58929306160626},
#       {'label': 'entrance', 'lat': 35.905733, 'lng': -78.588964}],
#      'distance': 8885,
#      'postalCode': '27614',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['1121 Falls River Ave Ste 101',
#       'Raleigh, NC 27614',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4c1a970f624b9c745a731204',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '1100 N Raleigh Blvd',
#      'lat': 35.79437917816129,
#      'lng': -78.61149321078761,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.79437917816129,
#        'lng': -78.61149321078761},
#       {'label': 'entrance', 'lat': 35.794896, 'lng': -78.611091}],
#      'distance': 5528,
#      'postalCode': '27610',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['1100 N Raleigh Blvd',
#       'Raleigh, NC 27610',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4b5b43d9f964a520abef28e3',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '2121 Tw Alexander Dr',
#      'lat': 35.920223663347286,
#      'lng': -78.81124180143277,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.920223663347286,
#        'lng': -78.81124180143277},
#       {'label': 'entrance', 'lat': 35.920633, 'lng': -78.81029}],
#      'distance': 17895,
#      'postalCode': '27560',
#      'cc': 'US',
#      'city': 'Morrisville',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['2121 Tw Alexander Dr',
#       'Morrisville, NC 27560',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4ba03734f964a520146237e3',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '7713 Lead Mine Rd Ste 35',
#      'lat': 35.88598855415606,
#      'lng': -78.66044955893506,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.88598855415606,
#        'lng': -78.66044955893506},
#       {'label': 'entrance', 'lat': 35.886787, 'lng': -78.659827}],
#      'distance': 5628,
#      'postalCode': '27615',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['7713 Lead Mine Rd Ste 35',
#       'Raleigh, NC 27615',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '5a737f28d41bb73f64b3875e',
#     'name': 'Transfer Co. Food Hall',
#     'location': {'address': '500 E Davie St',
#      'crossStreet': 'S. East Street',
#      'lat': 35.77504928706339,
#      'lng': -78.63215147752906,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.77504928706339,
#        'lng': -78.63215147752906}],
#      'distance': 7051,
#      'postalCode': '27601',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['500 E Davie St (S. East Street)',
#       'Raleigh, NC 27601',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '541552628'},
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4b471ddaf964a520912b26e3',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '1339 5th Ave',
#      'lat': 35.709039037496524,
#      'lng': -78.62313391036542,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.709039037496524,
#        'lng': -78.62313391036542}],
#      'distance': 14445,
#      'postalCode': '27529',
#      'cc': 'US',
#      'city': 'Garner',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['1339 5th Ave',
#       'Garner, NC 27529',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4bef27265e4aa593aaa558bb',
#     'name': 'Food Court at Crabtree Valley Mall',
#     'location': {'address': '4325 Crabtree Valley Ave',
#      'crossStreet': 'Upper Level, inside Crabtree Valley Mall',
#      'lat': 35.84064393776684,
#      'lng': -78.68107337134418,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.84064393776684,
#        'lng': -78.68107337134418}],
#      'distance': 3651,
#      'postalCode': '27612',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['4325 Crabtree Valley Ave (Upper Level, inside Crabtree Valley Mall)',
#       'Raleigh, NC 27612',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '47098379'},
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '5821f65070fc420f1abbbbe3',
#     'name': 'Bull City Street Food - Food Truck',
#     'location': {'lat': 35.81240954144765,
#      'lng': -78.6568470751411,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.81240954144765,
#        'lng': -78.6568470751411}],
#      'distance': 3199,
#      'cc': 'US',
#      'city': 'Cary',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['Cary, NC', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4b4a5466f964a520168426e3',
#     'name': 'Food Lion',
#     'location': {'address': '7440 Louisburg Rd Ste 101',
#      'lat': 35.874195401377314,
#      'lng': -78.53981225664715,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.874195401377314,
#        'lng': -78.53981225664715}],
#      'distance': 9956,
#      'postalCode': '27616',
#      'cc': 'US',
#      'neighborhood': 'Northeast Raleigh',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['7440 Louisburg Rd Ste 101',
#       'Raleigh, NC 27616',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4d36e22e4d8a6dcbead4643f',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '12345 Strickland Rd',
#      'lat': 35.90551068924585,
#      'lng': -78.70297890746737,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.90551068924585,
#        'lng': -78.70297890746737}],
#      'distance': 9379,
#      'postalCode': '27613',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['12345 Strickland Rd',
#       'Raleigh, NC 27613',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4b0ecda5f964a520415b23e3',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '8320 Litchford Rd Ste 100',
#      'lat': 35.8918459226783,
#      'lng': -78.6004295559481,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.8918459226783,
#        'lng': -78.6004295559481}],
#      'distance': 7009,
#      'postalCode': '27615',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['8320 Litchford Rd Ste 100',
#       'Raleigh, NC 27615',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4b085de7f964a5202f0a23e3',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '6209 Rock Quarry Rd',
#      'lat': 35.72335029798395,
#      'lng': -78.54784686785148,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.72335029798395,
#        'lng': -78.54784686785148},
#       {'label': 'entrance', 'lat': 35.722624, 'lng': -78.548623}],
#      'distance': 15274,
#      'postalCode': '27610',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['6209 Rock Quarry Rd',
#       'Raleigh, NC 27610',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4b9181baf964a5209cc133e3',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '7053 Knightdale Blvd',
#      'lat': 35.79989381524447,
#      'lng': -78.48989934325728,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.79989381524447,
#        'lng': -78.48989934325728}],
#      'distance': 14261,
#      'postalCode': '27545',
#      'cc': 'US',
#      'city': 'Knightdale',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['7053 Knightdale Blvd',
#       'Knightdale, NC 27545',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4c6064ba54ac0f47e373b521',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '405 S Main St',
#      'lat': 35.917513000998284,
#      'lng': -78.46496866277717,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.917513000998284,
#        'lng': -78.46496866277717}],
#      'distance': 18156,
#      'postalCode': '27571',
#      'cc': 'US',
#      'city': 'Rolesville',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['405 S Main St',
#       'Rolesville, NC 27571',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4b959680f964a520f2aa34e3',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '980 Kildaire Farm Rd',
#      'lat': 35.77233312908645,
#      'lng': -78.78324863313466,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.77233312908645,
#        'lng': -78.78324863313466}],
#      'distance': 14798,
#      'postalCode': '27511',
#      'cc': 'US',
#      'city': 'Cary',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['980 Kildaire Farm Rd',
#       'Cary, NC 27511',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4be8879aee96c9284535febf',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '217 Timber Dr',
#      'lat': 35.68506813782601,
#      'lng': -78.6053980886354,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.68506813782601,
#        'lng': -78.6053980886354}],
#      'distance': 17322,
#      'postalCode': '27529',
#      'cc': 'US',
#      'city': 'Garner',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['217 Timber Dr',
#       'Garner, NC 27529',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '5058fbb3c593f3e03f13fea8',
#     'name': 'Food Lion',
#     'location': {'address': '3609 Davis Dr',
#      'lat': 35.8220606354481,
#      'lng': -78.84920623900287,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.8220606354481,
#        'lng': -78.84920623900287},
#       {'label': 'entrance', 'lat': 35.82236, 'lng': -78.848931}],
#      'distance': 18898,
#      'postalCode': '27560',
#      'cc': 'US',
#      'city': 'Morrisville',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['3609 Davis Dr',
#       'Morrisville, NC 27560',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4c49deaeb5eec9b6890a56a5',
#     'name': 'BP Food Mart',
#     'location': {'address': '2500 Burlington Mills Rd',
#      'crossStreet': 'Capital Boulevard',
#      'lat': 35.91797466525108,
#      'lng': -78.54620102740898,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.91797466525108,
#        'lng': -78.54620102740898},
#       {'label': 'entrance', 'lat': 35.91789, 'lng': -78.546225}],
#      'distance': 12326,
#      'postalCode': '27587',
#      'cc': 'US',
#      'city': 'Wake Forest',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['2500 Burlington Mills Rd (Capital Boulevard)',
#       'Wake Forest, NC 27587',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d113951735',
#       'name': 'Gas Station',
#       'pluralName': 'Gas Stations',
#       'shortName': 'Gas Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4bca35be937ca593a668a792',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '9567 Chapel Hill Rd',
#      'lat': 35.80467442047724,
#      'lng': -78.81168770004486,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.80467442047724,
#        'lng': -78.81168770004486}],
#      'distance': 15870,
#      'postalCode': '27560',
#      'cc': 'US',
#      'city': 'Morrisville',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['9567 Chapel Hill Rd',
#       'Morrisville, NC 27560',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4d486e954c9ef04d0cb26a15',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '8745 Holly Springs Rd',
#      'crossStreet': 'Ten-Ten Road',
#      'lat': 35.69322898747734,
#      'lng': -78.77338297592385,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.69322898747734,
#        'lng': -78.77338297592385}],
#      'distance': 20082,
#      'postalCode': '27539',
#      'cc': 'US',
#      'city': 'Apex',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['8745 Holly Springs Rd (Ten-Ten Road)',
#       'Apex, NC 27539',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4b75edfff964a520ad2f2ee3',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '6904 Jenks Rd',
#      'lat': 35.75957905427491,
#      'lng': -78.87758929187287,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.75957905427491,
#        'lng': -78.87758929187287}],
#      'distance': 23098,
#      'postalCode': '27502',
#      'cc': 'US',
#      'city': 'Apex',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['6904 Jenks Rd', 'Apex, NC 27502', 'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4b75eea0f964a520ed2f2ee3',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '7971 Fayetteville Rd',
#      'lat': 35.66505103848507,
#      'lng': -78.69786282540333,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.66505103848507,
#        'lng': -78.69786282540333}],
#      'distance': 19933,
#      'postalCode': '27603',
#      'cc': 'US',
#      'city': 'Raleigh',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['7971 Fayetteville Rd',
#       'Raleigh, NC 27603',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4c2e616f452620a1cbbe1b0f',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '1160 US 1 Hwy',
#      'lat': 36.03933213778176,
#      'lng': -78.49708062621265,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.03933213778176,
#        'lng': -78.49708062621265},
#       {'label': 'entrance', 'lat': 36.038886, 'lng': -78.496982}],
#      'distance': 25882,
#      'postalCode': '27596',
#      'cc': 'US',
#      'city': 'Youngsville',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['1160 US 1 Hwy',
#       'Youngsville, NC 27596',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4b6f3174f964a5205ce32ce3',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '10105 US 70 Business Hwy W',
#      'lat': 35.63899738017664,
#      'lng': -78.44832202096732,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.63899738017664,
#        'lng': -78.44832202096732},
#       {'label': 'entrance', 'lat': 35.638709, 'lng': -78.448882}],
#      'distance': 28161,
#      'postalCode': '27520',
#      'cc': 'US',
#      'city': 'Clayton',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['10105 US 70 Business Hwy W',
#       'Clayton, NC 27520',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4af34c31f964a52069ec21e3',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '121 Sherron Rd Ste 210',
#      'lat': 35.97443309026006,
#      'lng': -78.7931450264343,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.97443309026006,
#        'lng': -78.7931450264343},
#       {'label': 'entrance', 'lat': 35.974144, 'lng': -78.792998}],
#      'distance': 20480,
#      'postalCode': '27703',
#      'cc': 'US',
#      'city': 'Durham',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['121 Sherron Rd Ste 210',
#       'Durham, NC 27703',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4c7d30559221236af76d7e3d',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '238 Pritchard Rd',
#      'lat': 35.69472387020214,
#      'lng': -78.41940424026545,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.69472387020214,
#        'lng': -78.41940424026545},
#       {'label': 'entrance', 'lat': 35.694927, 'lng': -78.419261}],
#      'distance': 25575,
#      'postalCode': '27527',
#      'cc': 'US',
#      'city': 'Clayton',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['238 Pritchard Rd',
#       'Clayton, NC 27527',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4bc35f484cdfc9b6593f9721',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '2837 Wendell Blvd',
#      'lat': 35.79558590795321,
#      'lng': -78.38047905708338,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.79558590795321,
#        'lng': -78.38047905708338},
#       {'label': 'entrance', 'lat': 35.795961, 'lng': -78.380211}],
#      'distance': 23963,
#      'postalCode': '27591',
#      'cc': 'US',
#      'city': 'Wendell',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['2837 Wendell Blvd',
#       'Wendell, NC 27591',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4b634707f964a520506f2ae3',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '4900 NC Highway 55 Ste 300',
#      'lat': 35.89885783879604,
#      'lng': -78.89820435504235,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.89885783879604,
#        'lng': -78.89820435504235}],
#      'distance': 24192,
#      'postalCode': '27713',
#      'cc': 'US',
#      'city': 'Durham',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['4900 NC Highway 55 Ste 300',
#       'Durham, NC 27713',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4c1e530f8b3aa59314e19b5f',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '3417 N Main St',
#      'lat': 35.62492036441893,
#      'lng': -78.72592522644725,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.62492036441893,
#        'lng': -78.72592522644725}],
#      'distance': 24939,
#      'postalCode': '27526',
#      'cc': 'US',
#      'city': 'Fuquay-Varina',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['3417 N Main St',
#       'Fuquay-Varina, NC 27526',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4b5227a0f964a520066c27e3',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '4711 Hope Valley Rd',
#      'lat': 35.92101403202063,
#      'lng': -78.9562765486974,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.92101403202063,
#        'lng': -78.9562765486974},
#       {'label': 'entrance', 'lat': 35.920842, 'lng': -78.956102}],
#      'distance': 29922,
#      'postalCode': '27707',
#      'cc': 'US',
#      'city': 'Durham',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['4711 Hope Valley Rd',
#       'Durham, NC 27707',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4b90f881f964a520e29c33e3',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '114 Wakelon St',
#      'lat': 35.832506883642885,
#      'lng': -78.3184387312674,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.832506883642885,
#        'lng': -78.3184387312674}],
#      'distance': 29093,
#      'postalCode': '27597',
#      'cc': 'US',
#      'city': 'Zebulon',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['114 Wakelon St',
#       'Zebulon, NC 27597',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4bec26c3415e20a14b25e7bb',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '2400 Holloway St',
#      'lat': 35.98938793720158,
#      'lng': -78.85939217473529,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.98938793720158,
#        'lng': -78.85939217473529}],
#      'distance': 25933,
#      'postalCode': '27703',
#      'cc': 'US',
#      'city': 'Durham',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['2400 Holloway St',
#       'Durham, NC 27703',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4b793824f964a5208fef2ee3',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '3022 Fayetteville St',
#      'lat': 35.96354851407689,
#      'lng': -78.90836406678196,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.96354851407689,
#        'lng': -78.90836406678196}],
#      'distance': 27886,
#      'postalCode': '27707',
#      'cc': 'US',
#      'city': 'Durham',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['3022 Fayetteville St',
#       'Durham, NC 27707',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4f1b04dfe4b0838231a8d24d',
#     'name': 'Costco Food Court',
#     'location': {'address': '1510 N Pointe Dr',
#      'lat': 36.0288844027112,
#      'lng': -78.91436201532181,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.0288844027112,
#        'lng': -78.91436201532181},
#       {'label': 'entrance', 'lat': 36.02899, 'lng': -78.913294}],
#      'distance': 32553,
#      'postalCode': '27705',
#      'cc': 'US',
#      'city': 'Durham',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['1510 N Pointe Dr',
#       'Durham, NC 27705',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4b3cc888f964a5203c8725e3',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '75 Glen Rd',
#      'lat': 35.60670048663048,
#      'lng': -78.56796871029229,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.60670048663048,
#        'lng': -78.56796871029229}],
#      'distance': 26576,
#      'postalCode': '27529',
#      'cc': 'US',
#      'city': 'Garner',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['75 Glen Rd', 'Garner, NC 27529', 'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4b70d5aaf964a520d0302de3',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '1508 Broad St',
#      'lat': 35.60457753670211,
#      'lng': -78.8025191702515,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.60457753670211,
#        'lng': -78.8025191702515}],
#      'distance': 29816,
#      'postalCode': '27526',
#      'cc': 'US',
#      'city': 'Fuquay-Varina',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['1508 Broad St',
#       'Fuquay-Varina, NC 27526',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4c9cdc06e9a7ef3b9dc83716',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '1338 N Main St',
#      'lat': 35.59038854199644,
#      'lng': -78.77661207712796,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.59038854199644,
#        'lng': -78.77661207712796},
#       {'label': 'entrance', 'lat': 35.590214, 'lng': -78.777582}],
#      'distance': 30177,
#      'postalCode': '27526',
#      'cc': 'US',
#      'city': 'Fuquay-Varina',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['1338 N Main St',
#       'Fuquay-Varina, NC 27526',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4c6152e254ac0f47ca9ab721',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '5279 N Roxboro Rd',
#      'lat': 36.07633786260021,
#      'lng': -78.91111629945873,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.07633786260021,
#        'lng': -78.91111629945873},
#       {'label': 'entrance', 'lat': 36.077286, 'lng': -78.91156}],
#      'distance': 36019,
#      'postalCode': '27712',
#      'cc': 'US',
#      'city': 'Durham',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['5279 N Roxboro Rd',
#       'Durham, NC 27712',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4c3a27f0dfb0e21e5ab6b1a8',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '50 Neuse River Pkwy Ste 11',
#      'lat': 35.64900029021209,
#      'lng': -78.39415316915971,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.64900029021209,
#        'lng': -78.39415316915971}],
#      'distance': 30644,
#      'postalCode': '27527',
#      'cc': 'US',
#      'city': 'Clayton',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['50 Neuse River Pkwy Ste 11',
#       'Clayton, NC 27527',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4c084530340720a1f0ea8293',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '3500 N Roxboro St',
#      'lat': 36.036324934431434,
#      'lng': -78.89149280240203,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.036324934431434,
#        'lng': -78.89149280240203}],
#      'distance': 31593,
#      'postalCode': '27704',
#      'cc': 'US',
#      'city': 'Durham',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['3500 N Roxboro St',
#       'Durham, NC 27704',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False},
#    {'id': '4c2e17bf7d85a59340af53f3',
#     'name': 'Food Lion Grocery Store',
#     'location': {'address': '3808 Guess Rd',
#      'lat': 36.05809483931359,
#      'lng': -78.92833989436454,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.05809483931359,
#        'lng': -78.92833989436454}],
#      'distance': 35664,
#      'postalCode': '27705',
#      'cc': 'US',
#      'city': 'Durham',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['3808 Guess Rd',
#       'Durham, NC 27705',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1657289139',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
Restaurants_Groceries_df = json_normalize(venues)
Restaurants_Groceries_df.head()
# Out:
# C:\Users\Harry Patria\AppData\Local\Temp\ipykernel_10744\2739364684.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   Restaurants_Groceries_df = json_normalize(venues)
#                          id                               name  \
# 0  4b22b0e6f964a520e04b24e3            Food Lion Grocery Store
# 1  4ed01e2b775bbb5f32900c8a               Target - Food Avenue
# 2  4b071d63f964a52087f722e3            Food Lion Grocery Store
# 3  4ba15048f964a520a9ab37e3  Food Bank of Central & Eastern NC
# 4  4b8ad3d9f964a520c38332e3            Food Lion Grocery Store
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '52f2ab2ebcbc57f1066b8b46', 'name': 'S...  v-1657289139    False
# 1  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...  v-1657289139    False
# 2  [{'id': '52f2ab2ebcbc57f1066b8b46', 'name': 'S...  v-1657289139    False
# 3  [{'id': '50328a8e91d4c4b30a586d6c', 'name': 'N...  v-1657289139    False
# 4  [{'id': '52f2ab2ebcbc57f1066b8b46', 'name': 'S...  v-1657289139    False
#
#             location.address  location.lat  location.lng  \
# 0          5426 Six Forks Rd     35.854910    -78.640727
# 1                North Hills     35.838319    -78.641821
# 2  4317 Fall Of The Neuse Rd     35.841043    -78.613129
# 3            3808 Tarheel Dr     35.831524    -78.607639
# 4          5633 Creedmoor Rd     35.858978    -78.682036
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 35.85490995058716...               1880
# 1  [{'label': 'display', 'lat': 35.8383193183181,...                103
# 2  [{'label': 'display', 'lat': 35.84104260746239...               2514
# 3  [{'label': 'display', 'lat': 35.83152395695958...               3073
# 4  [{'label': 'display', 'lat': 35.8589780724059,...               4396
#
#   location.postalCode location.cc location.city location.state  \
# 0               27609          US       Raleigh             NC
# 1               27609          US       Raleigh             NC
# 2               27609          US       Raleigh             NC
# 3               27609          US       Raleigh             NC
# 4               27612          US       Raleigh             NC
#
#   location.country                          location.formattedAddress  \
# 0    United States  [5426 Six Forks Rd, Raleigh, NC 27609, United ...
# 1    United States    [North Hills, Raleigh, NC 27609, United States]
# 2    United States  [4317 Fall Of The Neuse Rd, Raleigh, NC 27609,...
# 3    United States  [3808 Tarheel Dr (btwn Wolfpack Lane & St Alba...
# 4    United States  [5633 Creedmoor Rd, Raleigh, NC 27612, United ...
#
#                 location.crossStreet venuePage.id location.neighborhood
# 0                                NaN          NaN                   NaN
# 1                                NaN          NaN                   NaN
# 2                                NaN          NaN                   NaN
# 3  btwn Wolfpack Lane & St Albans Dr          NaN                   NaN
# 4                                NaN          NaN                   NaN

# %% [markdown]
# Now that we have a list of retail services, groceries and restaurants in the area, let's combine the two data-sets

# %%
Retail_df = Retail_df[['name', 'location.lat', 'location.lng']]

# %%
Restaurants_Groceries_df = Restaurants_Groceries_df[['name', 'location.lat', 'location.lng']]

# %%
Locations_Venue = pd.concat([Retail_df, Restaurants_Groceries_df], ignore_index=True)
Locations_Venue.rename(columns={'name':'Venue Name'}, 
                 inplace=True)
Locations_Venue.head()
# Out:
#                               Venue Name  location.lat  location.lng
# 0               Shops of Cameron Village     35.791233    -78.660793
# 1  Shops of Cameron Village CAT Bus Stop     35.791208    -78.660974
# 2                             Park Shops     35.785491    -78.667355
# 3                         Bass Pro Shops     35.830310    -78.770704
# 4                         Park Shops 201     35.785371    -78.667727

# %% [markdown]
# __Step 2:__ Now that we have the geographic coordinates of businesses in the area, let us determine the distance between each venue obtained from the foursquare API and each EVSE outlet location: <br>
# Procedure to calculate the distance has been obtained from this article in medium: <a href = "https://medium.com/@danalindquist/finding-the-distance-between-two-lists-of-geographic-coordinates-9ace7e43bb2f"> Finding the distance between two lists of geographic coordinates </a> by Dana Lindquist

# %%
# Create two dataframes with names of EVSE outlets and retail venues, and lat-long in degrees

Locations_EVSE = EVSE[['Station Name','Latitude', 'Longitude']].copy()

Locations_EVSE.rename(columns={'Station Name':'EVSE Station Name'}, 
                 inplace=True)

# %%
# add columns with radians for latitude and longitude
Locations_EVSE[['Latitude', 'Longitude']] = (
    np.radians(Locations_EVSE.loc[:,['Latitude', 'Longitude']])
)
Locations_Venue[['location.lat', 'location.lng']] = (
    np.radians(Locations_Venue.loc[:,['location.lat', 'location.lng']])
)

# %% [markdown]
# The distance computed here is a haversine distance. This assumes the earth is a true sphere which makes for a relatively fast computation. The sklearn computation assumes the radius of the sphere is 1, so to get the distance in miles we multiply the output of the sklearn computation by 3959 miles, the average radius of the earth. To get the distance in kilometers this number would be 6371 km.

# %%
dist = sklearn.neighbors.DistanceMetric.get_metric('haversine')
dist_matrix = (dist.pairwise
    (Locations_EVSE[['Latitude', 'Longitude']],
     Locations_Venue[['location.lat', 'location.lng']])*6371
)
# Note that 6371 is the radius of the earth in km
df_dist_matrix = (
    pd.DataFrame(dist_matrix,index=Locations_EVSE['EVSE Station Name'], 
                 columns=Locations_Venue['Venue Name'])
)
# Out:
# c:\Users\Harry Patria\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\neighbors\_distance_metric.py:10: FutureWarning: sklearn.neighbors.DistanceMetric has been moved to sklearn.metrics.DistanceMetric in 1.0. This import path will be removed in 1.3
#   warnings.warn(

# %%
df_dist_matrix.head()
# Out:
# Venue Name                            Shops of Cameron Village  \
# EVSE Station Name
# DUKE ENERGY                                         207.864559
# City of Raleigh - Municipal Building                  2.114912
# City of Raleigh - Downtown                            2.512168
# Modern Nissan - Concord                             182.871199
# Fred Anderson Nissan                                 87.476766
#
# Venue Name                            Shops of Cameron Village CAT Bus Stop  \
# EVSE Station Name
# DUKE ENERGY                                                      207.848091
# City of Raleigh - Municipal Building                               2.125133
# City of Raleigh - Downtown                                         2.520966
# Modern Nissan - Concord                                          182.854637
# Fred Anderson Nissan                                              87.469043
#
# Venue Name                            Park Shops  Bass Pro Shops  \
# EVSE Station Name
# DUKE ENERGY                           207.112806      199.776821
# City of Raleigh - Municipal Building    2.293743       12.843331
# City of Raleigh - Downtown              2.578477       13.146853
# Modern Nissan - Concord               182.147432      174.371684
# Fred Anderson Nissan                   86.687799       89.215991
#
# Venue Name                            Park Shops 201  Shops At Mcneil Pointe  \
# EVSE Station Name
# DUKE ENERGY                               207.076829              211.470816
# City of Raleigh - Municipal Building        2.320789                4.086690
# City of Raleigh - Downtown                  2.601618                4.477435
# Modern Nissan - Concord                   182.111710              186.388969
# Fred Anderson Nissan                       86.664865               90.708159
#
# Venue Name                            Shops at Brennan Station  \
# EVSE Station Name
# DUKE ENERGY                                         209.861712
# City of Raleigh - Municipal Building                 13.894064
# City of Raleigh - Downtown                           14.358494
# Modern Nissan - Concord                             184.191349
# Fred Anderson Nissan                                 98.474145
#
# Venue Name                            Shops at Town Station  Flip Flop Shops  \
# EVSE Station Name
# DUKE ENERGY                                      194.649437       207.744806
# City of Raleigh - Municipal Building              14.743878         7.738003
# City of Raleigh - Downtown                        14.834826         8.191014
# Modern Nissan - Concord                          169.568757       182.411820
# Fred Anderson Nissan                              82.219775        92.196897
#
# Venue Name                            Shops at Oberlin Court  ...  \
# EVSE Station Name                                             ...
# DUKE ENERGY                                       208.165049  ...
# City of Raleigh - Municipal Building                2.628716  ...
# City of Raleigh - Downtown                          3.067138  ...
# Modern Nissan - Concord                           183.129647  ...
# Fred Anderson Nissan                               88.215571  ...
#
# Venue Name                            Food Lion Grocery Store  \
# EVSE Station Name
# DUKE ENERGY                                        198.938751
# City of Raleigh - Municipal Building                30.475037
# City of Raleigh - Downtown                          30.892105
# Modern Nissan - Concord                            172.543602
# Fred Anderson Nissan                               105.666144
#
# Venue Name                            Food Lion Grocery Store  \
# EVSE Station Name
# DUKE ENERGY                                        193.736678
# City of Raleigh - Municipal Building                31.519437
# City of Raleigh - Downtown                          31.897069
# Modern Nissan - Concord                            167.381970
# Fred Anderson Nissan                               102.518520
#
# Venue Name                            Costco Food Court  \
# EVSE Station Name
# DUKE ENERGY                                  196.370826
# City of Raleigh - Municipal Building          37.026566
# City of Raleigh - Downtown                    37.437899
# Modern Nissan - Concord                      169.722508
# Fred Anderson Nissan                         109.756971
#
# Venue Name                            Food Lion Grocery Store  \
# EVSE Station Name
# DUKE ENERGY                                        211.074442
# City of Raleigh - Municipal Building                20.274784
# City of Raleigh - Downtown                          19.813195
# Modern Nissan - Concord                            187.535261
# Fred Anderson Nissan                                71.979064
#
# Venue Name                            Food Lion Grocery Store  \
# EVSE Station Name
# DUKE ENERGY                                        190.248431
# City of Raleigh - Municipal Building                24.082355
# City of Raleigh - Downtown                          23.786058
# Modern Nissan - Concord                            166.466406
# Fred Anderson Nissan                                64.056022
#
# Venue Name                            Food Lion Grocery Store  \
# EVSE Station Name
# DUKE ENERGY                                        192.217080
# City of Raleigh - Municipal Building                24.119136
# City of Raleigh - Downtown                          23.782771
# Modern Nissan - Concord                            168.589199
# Fred Anderson Nissan                                63.085343
#
# Venue Name                            Food Lion Grocery Store  \
# EVSE Station Name
# DUKE ENERGY                                        199.034568
# City of Raleigh - Municipal Building                40.965767
# City of Raleigh - Downtown                          41.394793
# Modern Nissan - Concord                            172.212138
# Fred Anderson Nissan                               115.040602
#
# Venue Name                            Food Lion Grocery Store  \
# EVSE Station Name
# DUKE ENERGY                                        227.394111
# City of Raleigh - Municipal Building                26.716136
# City of Raleigh - Downtown                          26.385087
# Modern Nissan - Concord                            203.704491
# Fred Anderson Nissan                                84.575383
#
# Venue Name                            Food Lion Grocery Store  \
# EVSE Station Name
# DUKE ENERGY                                        198.580637
# City of Raleigh - Municipal Building                36.351329
# City of Raleigh - Downtown                          36.774346
# Modern Nissan - Concord                            171.937466
# Fred Anderson Nissan                               110.674890
#
# Venue Name                            Food Lion Grocery Store
# EVSE Station Name
# DUKE ENERGY                                        196.722636
# City of Raleigh - Municipal Building                40.313940
# City of Raleigh - Downtown                          40.731436
# Modern Nissan - Concord                            169.940959
# Fred Anderson Nissan                               112.967235
#
# [5 rows x 100 columns]

# %% [markdown]
# __Step 3:__ Now let's count the number of EVSE Stations that are at distance which is less than or equal to 5 km from the prospective venues

# %%
# Defining an indicator matrix

df_indicator_matrix = df_dist_matrix.le(5).astype(int)
df_indicator_matrix.shape
# Out:
# (640, 100)

# %%
# Obtain the sum of each venue (column) in the indicator matrix - this gives the total number of EVSEs within 5 km of the said venue

Num_EVSE = df_indicator_matrix.sum(axis = 0)
Num_EVSE.head(30)
# Out:
# Venue Name
# Shops of Cameron Village                       34
# Shops of Cameron Village CAT Bus Stop          34
# Park Shops                                     34
# Bass Pro Shops                                 11
# Park Shops 201                                 34
# Shops At Mcneil Pointe                         30
# Shops at Brennan Station                        5
# Shops at Town Station                          11
# Flip Flop Shops                                13
# Shops at Oberlin Court                         42
# shops of Lafayette Village                      5
# Shops                                          12
# Suzio's Boutique (at Shops of Baileywick)       5
# Shopsmith Repair/Woodworking Academy           15
# Rainbow Shops                                   4
# Rainbow Shops                                   4
# Fun and Fabulous (at Shops of Baileywick)       5
# Fancy That by A&E (at Shops of Baileywick)      5
# Seaboard Ace Hardware                          33
# Blake Street Shops & Studios                   33
# The Shops at Garner Plaza                       0
# Lafayette Village                               8
# The Shops at Preston                           15
# Target                                          4
# Shop Small Super Shop                          32
# The Shops at Timber Landing shopping center     0
# Rainbow Shops                                   2
# Paradies Shops                                  6
# Rainbow Shops                                   0
# Market Shoppes at the State Farmers Market     32
# dtype: int64

# %%
# Select venues that have less than 2 EVSE outlets within 5 kms
venue_names = Num_EVSE[(Num_EVSE <= 2)]

# Use previously selected venue names and identify the corresponding coordinates, 
# based on dataframe previously geneerated from Foursquare API data 
Venue_Selected = Locations_Venue.loc[Locations_Venue['Venue Name'].isin(venue_names.index)]
# Also convert the latitudes and longitudes back to degrees from radians
Venue_Selected[['location.lat', 'location.lng']] = (
    np.degrees(Locations_Venue.loc[:,['location.lat', 'location.lng']])
)

Venue_Selected.head()
# Out:
# c:\Users\Harry Patria\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:3636: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#                                      Venue Name  location.lat  location.lng
# 14                                Rainbow Shops     35.873154    -78.582456
# 15                                Rainbow Shops     35.798592    -78.579493
# 20                    The Shops at Garner Plaza     35.704787    -78.611581
# 25  The Shops at Timber Landing shopping center     35.684866    -78.616349
# 26                                Rainbow Shops     35.798753    -78.507796

# %% [markdown]
# __Step 4:__ Let us now __cluster__ those locations to create centers of zones containing good locations. Those zones, their centers and addresses will be the final result of our analysis.

# %%
number_of_clusters = 7
Venue_Selected_xys = Venue_Selected[['location.lat', 'location.lng']].values
kmeans = KMeans(n_clusters=number_of_clusters, random_state=0).fit(Venue_Selected_xys)

cluster_centers = kmeans.cluster_centers_

print(cluster_centers)
print(kmeans.labels_)
# Out:
# [[ 35.88864173 -78.63439532]
#  [ 35.71338287 -78.6195781 ]
#  [ 35.99067229 -78.8872379 ]
#  [ 35.66202439 -78.77713451]
#  [ 35.9074968  -78.49017188]
#  [ 35.72216287 -78.39215944]
#  [ 35.479688   -79.178982  ]]
# [0 1 1 1 4 1 1 1 4 0 3 0 1 2 2 3 6 0 0 0 0 0 1 4 0 1 2 0 1 0 0 1 4 4 3 1 3
#  3 3 3 4 5 2 5 5 2 3 2 5 2 2 1 3 3 2 5 2 2]

# %% [markdown]
# ## Results <a name="results"></a>

# %%
# add clustering labels

Venue_labels = Venue_Selected

Venue_labels.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
Venue_labels.head()
# Out:
#     Cluster Labels                                   Venue Name  location.lat  \
# 14               0                                Rainbow Shops     35.873154
# 15               1                                Rainbow Shops     35.798592
# 20               1                    The Shops at Garner Plaza     35.704787
# 25               1  The Shops at Timber Landing shopping center     35.684866
# 26               4                                Rainbow Shops     35.798753
#
#     location.lng
# 14    -78.582456
# 15    -78.579493
# 20    -78.611581
# 25    -78.616349
# 26    -78.507796

# %%
# create map

map_clusters = folium.Map(location=[35.78, -78.64], zoom_start=11)

# set color scheme for the clusters
x = np.arange(number_of_clusters)
ys = [i + x + (i*x)**2 for i in range(number_of_clusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(Venue_labels['location.lat'], Venue_labels['location.lng'], Venue_labels['Venue Name'], Venue_labels['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d9827651951575ad0f8b11a6fe4ede03 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d9827651951575ad0f8b11a6fe4ede03&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d9827651951575ad0f8b11a6fe4ede03 = L.map(
#                 &quot;map_d9827651951575ad0f8b11a6fe4ede03&quot;,
#                 {
#                     center: [35.78, -78.64],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_201f959087bcab1a6a13a195647f65d4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d9827651951575ad0f8b11a6fe4ede03);
#
#
#             var circle_marker_5fc0ccf1c29a5f4aae0dbc8ce62b48bc = L.circleMarker(
#                 [35.873154, -78.58245600000001],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff0000&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d9827651951575ad0f8b11a6fe4ede03);
#
#
#         var popup_ac36ccafe93d8d28e89810895ad290a7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5c1feaccc47435573fcece1e669ace29 = $(`&lt;div id=&quot;html_5c1feaccc47435573fcece1e669ace29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rainbow Shops Cluster 0&lt;/div&gt;`)[0];
#             popup_ac36ccafe93d8d28e89810895ad290a7.setContent(html_5c1feaccc47435573fcece1e669ace29);
#
#
#         circle_marker_5fc0ccf1c29a5f4aae0dbc8ce62b48bc.bindPopup(popup_ac36ccafe93d8d28e89810895ad290a7)
#         ;
#
#
#
#
#             var circle_marker_2766887d9b8929e0fc1ee651ac44ac5f = L.circleMarker(
#                 [35.7985924, -78.5794926],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8000ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8000ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d9827651951575ad0f8b11a6fe4ede03);
#
#
#         var popup_6f798b66685d12bd92e95e255bcfbc2b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a1d0fcd9ac533259031a1c315f28aa2c = $(`&lt;div id=&quot;html_a1d0fcd9ac533259031a1c315f28aa2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rainbow Shops Cluster 1&lt;/div&gt;`)[0];
#             popup_6f798b66685d12bd92e95e255bcfbc2b.setContent(html_a1d0fcd9ac533259031a1c315f28aa2c);
#
#
#         circle_marker_2766887d9b8929e0fc1ee651ac44ac5f.bindPopup(popup_6f798b66685d12bd92e95e255bcfbc2b)
#         ;
#
#
#
#
#             var circle_marker_c40def52c9d42496ace6a68f77789894 = L.circleMarker(
#                 [35.704786999999996, -78.611581],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8000ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8000ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d9827651951575ad0f8b11a6fe4ede03);
#
#
#         var popup_d790def509599217570668f582622cf0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_04cf82ac9fd15faecbd8346d84cf1cca = $(`&lt;div id=&quot;html_04cf82ac9fd15faecbd8346d84cf1cca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The Shops at Garner Plaza Cluster 1&lt;/div&gt;`)[0];
#             popup_d790def509599217570668f582622cf0.setContent(html_04cf82ac9fd15faecbd8346d84cf1cca);
#
#
#         circle_marker_c40def52c9d42496ace6a68f77789894.bindPopup(popup_d790def509599217570668f582622cf0)
#         ;
#
#
#
#
#             var circle_marker_79b6d9b75d06460eff3d68095caabbdb = L.circleMarker(
#                 [35.68486612730721, -78.61634901598707],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8000ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8000ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;ro

# %% [markdown]
# Finally, let's reverse geocode those k-means clustering centers to get the addresses which can be presented to stakeholders.

# %%
geolocator = Nominatim(user_agent="foursquare_agent")

lat = 35.74137968
long = -78.59448015

for lat, long in cluster_centers:
    location = geolocator.reverse([lat, long])
    print(location.address, "\n")
# Out:
# Wildwood Green Golf Club, 3000, Columbine Drive, Lake Lynn, Wake County, North Carolina, 27613, United States of America
#
# 533, Greenwood Drive, Greenwood Forest, Kildaire Farms, Cary, Wake County, North Carolina, 27511, United States of America
#
# Marks Creek Road, Riley Hill, Wake County, North Carolina, 27545, United States of America
#
# 1301, Person Street, Hayes, Durham, Durham County, North Carolina, 27703, United States of America
#
# Quail Hill Street, Five Points, Fuquay-Varina, Wake County, North Carolina, 27526, United States of America
#
# 9475, Millbrook Woods Drive, Millbrook Green Apartments, Mini City, Raleigh, Wake County, North Carolina, 27604, United States of America
#
# 1162, New Rand Road, Garner, Wake County, North Carolina, 27529, United States of America

# %% [markdown]
# ## Discussion <a name="discussion"></a>

# %% [markdown]
# While this project does a good job demonstrating how data science can be used to inform energy infrastructure siting decisions, the analysis could be improved in many different ways. A few are listed here but should not be considered an exhaustive list:<br> <br> (a) Socio-economic as well as demographic factors need to be considered when prioritizing siting locations. Here is an <a href = "https://theicct.org/sites/default/files/publications/Expanding-access-electric-mobility_ICCT-Briefing_06122017_vF.pdf"> excellent article </a> summarizing policies and actions being taken to expand access to electric transporation among low income groups and apartment dwellers <br> <br>
# (b) Siting analysis may need to take into considerations the practicality of EV charging installations - zoning permits, transmission capacity to support supply of electricity for EV charging etc. are some factors that could affect EV charging installations <br> <br>
# (c) Demand for EV charging is another really important factor. If there are not enough EVs driving through the region that need to stop and charge - there may not be any incentive for installation of EV chargers. North Carolina DMV has recently started releasing <a href = "https://www.ncdot.gov/initiatives-policies/environmental/climate-change/Pages/zev-registration-data.aspx"> EV registration data in NC counties </a>. This could indicate how many EV owners currently reside in NC. Market research could also be performed to explore the out-of-state EV traffic passing through NC.

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# This project provides a simple example of utilization of k-means clustering technique in the clean energy sector. Data cleaning and manipulation, application of algorithms, and subsequent data visualization are the primary steps involved in any problem that needs to be solved using data analytics. I hope that this notebook provides a source of reference for those starting to explore data-driven solutions to their business problems.
